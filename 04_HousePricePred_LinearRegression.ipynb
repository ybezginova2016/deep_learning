# %% [markdown]
# # 4.0 House Price prediction - Linear Regression
#
# [First Machine Learning Program with Python / Jupyter](https://www.youtube.com/watch?v=LGHIPdFwn2k&ab_channel=PraveenKumar)
#
# [Predicting house prices using Linear regression](https://medium.com/coding-today/predicting-house-prices-using-linear-regression-8f6de5ad85b5)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
house_data = pd.read_csv('/Users/yuliabezginova/PycharmProjects/deep_learning/kc_house_data.csv')
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
house_data.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
house_data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
plt.scatter(house_data['sqft_living'], house_data['price']);

# %%
house_data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
house_hist = house_data[['price', 
           'bedrooms', 'bathrooms', 
           'sqft_living','sqft_lot', 'floors', 
           'waterfront', 'view', 'condition', 
           'grade', 'sqft_above', 'sqft_basement', 
           'yr_built', 'yr_renovated']].copy()

# %%
house_hist.hist(bins=50, figsize=(20, 20));

# %% [markdown]
# ### Checking for missings values

# %%
pd.DataFrame(round(house_data.isna().mean() * 100, )).style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_8b1d3_row0_col0, #T_8b1d3_row1_col0, #T_8b1d3_row2_col0, #T_8b1d3_row3_col0, #T_8b1d3_row4_col0, #T_8b1d3_row5_col0, #T_8b1d3_row6_col0, #T_8b1d3_row7_col0, #T_8b1d3_row8_col0, #T_8b1d3_row9_col0, #T_8b1d3_row10_col0, #T_8b1d3_row11_col0, #T_8b1d3_row12_col0, #T_8b1d3_row13_col0, #T_8b1d3_row14_col0, #T_8b1d3_row15_col0, #T_8b1d3_row16_col0, #T_8b1d3_row17_col0, #T_8b1d3_row18_col0, #T_8b1d3_row19_col0, #T_8b1d3_row20_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8b1d3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b1d3_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_8b1d3_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8b1d3_level0_row1" class="row_heading level0 row1" >date</th>
# ...

# %%
# define the input data (x) and define the output / prediction(y)
X = house_data.drop(['price', 'id', 'date', 'zipcode'], axis=1)
y = house_data['price']

# %% [markdown]
# ## Training the data on a LinearRegression model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression() # creating an instance of Linear Regression

# %% [markdown]
# ### Splitting the data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=5)

# %%
# Let's check the shape of X_train, y_train datasets
print(X_train.shape)
print(y_train.shape)

print(X_test.shape)
print(y_test.shape)
# Out:
# (16209, 17)
# (16209,)
# (5404, 17)
# (5404,)

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ### StandardScaler

# %%
# Standard Scaler
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# ### Training the data

# %%
# call the fit() method to train the data
# model.fit(X_train, y_train)

# %%
# test / score the model - accuracy
# model.score(X_test, y_test)

# %% [markdown]
# ***Thank you for going through this project. Your comments are more then welcome to ybezginova2021@gmail.com***
#
# ***Best wishes,***
#
# ***Yulia***
