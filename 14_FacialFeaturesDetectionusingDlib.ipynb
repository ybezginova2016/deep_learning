# %% [markdown]
# # 14.0 - ***Deep Learning*** - Facial Features Detection using Dlib
#
# [Face Landmark Detection using dlib - Python OpenCV](https://www.youtube.com/watch?v=SIZNf_Ydplg&ab_channel=MisbahMohammed)
#
# Github [Face recognition using dlib](https://github.com/trygvea/face-recognition-dlib)
#
# ![Screen%20Shot%202022-11-25%20at%202.02.40%20AM.png](attachment:Screen%20Shot%202022-11-25%20at%202.02.40%20AM.png)

# %%
# !wget   http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2 # DOWNLOAD LINK

# !bunzip2 /content/shape_predictor_68_face_landmarks.dat.bz2

datFile =  "/content/shape_predictor_68_face_landmarks.dat"
# Out:
# /bin/bash: wget: command not found
# bunzip2: Can't open input file /content/shape_predictor_68_face_landmarks.dat.bz2: No such file or directory.

# %%
import cv2
import dlib

# %% [markdown]
# ![Screen%20Shot%202022-11-25%20at%202.06.12%20AM.png](attachment:Screen%20Shot%202022-11-25%20at%202.06.12%20AM.png)

# %%
cap = cv2.VideoCapture(0)

# %%
hog_face_detector = dlib.get_frontal_face_detector()

# %%
dlib_facelandmark = dlib.shape_predictor(datFile)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 dlib_facelandmark = dlib.shape_predictor(datFile)
#
# RuntimeError: Unable to open /content/shape_predictor_68_face_landmarks.dat

# %% [markdown]
# ***Thank you for going through this project. Your comments are more then welcome to ybezginova2021@gmail.com***
#
# ***Best wishes,***
#
# ***Yulia***
